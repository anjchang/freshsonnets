# %%
import random
import markovify
from random import choice
from random import randint

# %% [raw]
# #grab sonnets and save to text file
# import urllib.request
# from random import randint
# from bs4 import BeautifulSoup
# num = randint(1,154) #random sonnet from shapespeare
#
# def fetch_all_sonnets():
#     output=""
#     for num in range(1,154):
#         old_poems = 'http://www.literaturepage.com/read/shakespeare_sonnets-%d.html' % (num)
#         website = old_poems
#         page = urllib.request.urlopen(website)
#         html_doc = page.read()
#         soup = BeautifulSoup(html_doc, 'html.parser')
#         textfetch = soup.find('p', attrs={'class':'readingpoetry'})
#         output = output+textfetch.text
#     return output
#
# sonnetlines = fetch_all_sonnets()
#
# with open("sonnetall2021.txt", "w") as text_file:
#     print(sonnetlines, file=text_file)

# %% [raw]
# #Grab lyrics and save to text file
# import lyricsgenius as lg
# genius = lg.Genius('xxxxxxxxxxxxxxx', \
#                    skip_non_songs=True, excluded_terms=["(Remix)", "(Live)"], remove_section_headers=True)
#
#
# def get_lyrics(arr, k):
#     c = 0
#     for name in arr:
#         try:
#             songs = (genius.search_artist(name, max_songs=k, sort='popularity')).songs
#             s = [song.lyrics for song in songs]
#             file.write("\n".join(s))
#             c += 1
#             print(f"Songs grabbed:{len(s)}")
#         except:
#             print(f"some exception at {name}: {c}")
# file = open("/path/to/willsmith.txt", "w")
# artists = ['Will Smith']
# get_lyrics(artists, 30)

# %%
with open("sonnetall2021.txt",'r+') as file:
    sonnet= file.readlines()
    file.seek(0)
    file.writelines(line for line in sonnet if line.strip())
    file.truncate()

# %%
with open("willsmith.txt",'r+') as file:
    will = file.readlines()
    file.seek(0)
    file.writelines(line for line in will if line.strip())
    file.truncate()

# %%
def pickfrom(verses,no):
    #get a random no of lines from list of verses
    output="";
    lowerbound = len(verses)-no
    randomspot = randint(0,lowerbound)
    for i in range(0,no):
        output = output + verses[randomspot  + i] 
    return output

# %%
## Compose new Fresh Sonnets Output
output = ""
for i in range(1564): #year that shakespeare was born
    output= output+ pickfrom(will,3) 
    output= output + pickfrom(sonnet,2)

## Format into Sonnet Form octet then sextet
novel=""
count=0
octet=True 
chunked = output.split("\n")
for i in range(len(chunked)):
    count= count+1
    if count%8==0 and octet:
        chunked[i] = chunked[i]+'\n\n' 
        octet = not octet
        count=0
    elif count%6==0 and not octet:
        chunked[i] = chunked[i]+'\n\n' 
        octet = not octet
        count=0
print(chunked)

print(len(output.split())) #count those words!
# Out:
# ['Somewhere to clear my mind (just cruisin)', "Just cruisin (I'm just cruisin)", "Where, baby, I don't care (just cruisin)", "And simple truth miscall'd simplicity,", 'And captive good attending captain ill:', 'Ha, ha', 'Excuse me Miss, can we chat for a second', "I'd ask how you doin', but you fine I reckon\n\n", 'Shall you pace forth; your praise shall still find room', 'Even in the eyes of all posterity', '{The Wild Wild..}', 'The Wild Wild West', 'Now Dad this is a very sensitive subject', 'That they behold, and see not what they see?\n\n', 'They know what beauty is, see where it lies,', 'Delayed', 'Negative voices, many, once in prison for unwise choices that he once', 'Made*', 'Now all is done, save what shall have no end:', 'Mine appetite I never more will grind', 'Galaxy defenders (galaxy defenders)', 'Here come the Men in Black (oh, here they come)\n\n', "They won't let you remember (won't let you remember)", 'Attending on his golden pilgrimage:', 'But when from highmost pitch, with weary car,', 'Wooooo', 'Uh, uh, uh, uh', 'Haha, haha\n\n', "Ere you were born was beauty's summer dead.", "Let not my love be call'd idolatry,", 'With his bears and lions a brass band and more (What?)', 'With his forty fakirs (Oh!) his cooks, his bakers (Oh!)', 'His birds that warble on key (Oh!)', 'And scarcely greet me with that sun, thine eye,', 'When love, converted from the thing it was,', 'Highly ranked black blank I.D. card\n\n', 'So disregard what you think you saw', 'Put that phone down now', "After a thousand victories once foil'd,", 'Is from the book of honour razed quite,', 'Right from Cuba-Cuba, I just bite it', "It's for the look, I don't light it\n\n", 'Illway the an-may on the ance-day oor-flay', 'Which time and thoughts so sweetly doth deceive, ', 'And that thou teachest how to make one twain,', "Don't sleep I'm gonna freak this (yeah, yeah)", 'You know you like this when I freak this (yeah, yeah)', "Watch me I'm bout to freak this (yeah, yeah)", 'Hung with the trophies of my lovers gone,', 'Who all their parts of me to thee did give,\n\n', 'Now, try your best to stay calm', 'Brush up your Friday salaam', 'Then come and meet his spectacular coterie', "Featur'd like him, like him with friends possess'd,", "Desiring this man's art, and that man's scope,", 'Come on everyone, new millennium\n\n', 'Here it comes another year', 'Everyone, new millennium', 'In singleness the parts that thou shouldst bear. ', 'Mark how one string, sweet husband to another,', "They won't let you remember", 'Nah nah nah', 'The good guys dress in black remember that', 'Sweet beauty hath no name, no holy bower,\n\n', "But is profan'd, if not lives in disgrace.", "With Artemus, from the start of this, runnin' the game", "James West, tamin' the West, so remember the name", 'Now who ya gonna call?', 'That I an accessary needs must be,', 'To that sweet thief which sourly robs from me.\n\n', 'Your ex-boyfriends Mike and Ike are both Lemonheads', "I ain't tryin ta player hate girl I know", 'That you go with Bazooka Joe', 'Be, as thy presence is, gracious and kind,', 'Or to thyself at least kind-hearted prove:', 'Uh', "On your mark ready set let's go, dance floor pro", 'I know you know I go psycho\n\n', 'On purpose laid to make the taker mad:', 'Mad in pursuit and in possession so;', 'She said she watched my TV show and I was very silly', 'Told her I was from Philly, she looked at me said really?', 'And judgin from her t-shirt I could tell that she was chilly', 'Which alters when it alteration finds,\n\n', 'Or bends with the remover to remove:', 'So I gave her my sweater, she said her name was Etta', 'She said she come from Cuba and she just had bought a Jetta', "She said she glad I met her, let's go somewhere together", 'So thou be good, slander doth but approve', "Thy worth the greater being woo'd of time;", '(Forever chasing forever)', "Yo, if you can't dance, it's cool to get up now\n\n", "Yeah see usually y'all stand off on the side", 'Like him that tra ...
# 59886

# %%
#Print to text file
with open('freshsonnets.txt', 'w') as f:
    for line in chunked:
        f.write(line+'\n')

#Print to PDF
from fpdf import FPDF


class PDF(FPDF):
    def header(self):
        # Setting font: helvetica bold 15
        self.set_font("helvetica", "B", 15)
        # Calculating width of title and setting cursor position:
        width = self.get_string_width(self.title) + 6
        self.set_x((210 - width) / 2)
        # Setting colors for frame, background and text:
        self.set_draw_color(0, 80, 180)
        self.set_fill_color(200, 220, 255)
        self.set_text_color(220, 50, 50)
        # Setting thickness of the frame (1 mm)
        self.set_line_width(1)
        # Printing title:
        self.cell(width, 9, self.title, 1, 1, "C", True)
        # Performing a line break:
        self.ln(10)

    def footer(self):
        # Setting position at 1.5 cm from bottom:
        self.set_y(-15)
        # Setting font: helvetica italic 8
        self.set_font("helvetica", "I", 8)
        # Setting text color to gray:
        self.set_text_color(128)
        # Printing page number
        self.cell(0, 10, f"Page {self.page_no()}", 0, 0, "C")

    def chapter_title(self, label):
        # Setting font: helvetica 12
        self.set_font("helvetica", "", 12)
        # Setting background color
        self.set_fill_color(200, 220, 255)
        # Printing chapter name:
        self.cell(0, 6, f"{label}", 0, 1, "C", True)
        # Performing a line break:
        self.ln(4)

    def chapter_body(self, filepath):
        # Reading text file:
        with open(filepath, "rb") as fh:
            txt = fh.read().decode("latin-1")
        # Setting font: Times 12
        self.set_font("Times", size=12)
        # Printing justified text:
        self.multi_cell(0, 5, txt)
        # Performing a line break:
        self.ln()
        # Final mention in italics:
        self.set_font(style="I")
        self.cell(0, 5, "(--end--)")

    def print_chapter(self, title, filepath):
        self.add_page()
        self.chapter_title(title)
        self.chapter_body(filepath)


pdf = PDF()
pdf.set_title("Fresh Sonnets")
pdf.set_author("by anjchang for nanogenmo 2021")
pdf.print_chapter("Will Shakespeare Sonnets X Will Smith Rap | nanogenmo 2021 by anjchang", "freshsonnets.txt")
pdf.output("freshsonnets.pdf")
