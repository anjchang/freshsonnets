# %%
import random
import markovify
from random import choice
from random import randint

# %% [markdown]
# #grab sonnets and save to text file
# import urllib.request
# from random import randint
# from bs4 import BeautifulSoup
# num = randint(1,154) #random sonnet from shapespeare
#
# def fetch_all_sonnets():
#     output=""
#     for num in range(1,154):
#         old_poems = 'http://www.literaturepage.com/read/shakespeare_sonnets-%d.html' % (num)
#         website = old_poems
#         page = urllib.request.urlopen(website)
#         html_doc = page.read()
#         soup = BeautifulSoup(html_doc, 'html.parser')
#         textfetch = soup.find('p', attrs={'class':'readingpoetry'})
#         output = output+textfetch.text
#     return output
#
# sonnetlines = fetch_all_sonnets()
#
# with open("sonnetall2021.txt", "w") as text_file:
#     print(sonnetlines, file=text_file)

# %% [raw]
# #Grab lyrics and save to text file
# import lyricsgenius as lg
# genius = lg.Genius('xxxxxxxxxxxxxxx', \
#                    skip_non_songs=True, excluded_terms=["(Remix)", "(Live)"], remove_section_headers=True)
#
#
# def get_lyrics(arr, k):
#     c = 0
#     for name in arr:
#         try:
#             songs = (genius.search_artist(name, max_songs=k, sort='popularity')).songs
#             s = [song.lyrics for song in songs]
#             file.write("\n".join(s))
#             c += 1
#             print(f"Songs grabbed:{len(s)}")
#         except:
#             print(f"some exception at {name}: {c}")
# file = open("/path/to/willsmith.txt", "w")
# artists = ['Will Smith']
# get_lyrics(artists, 30)

# %%
with open("sonnetall2021.txt",'r+') as file:
    sonnet= file.readlines()
    file.seek(0)
    file.writelines(line for line in sonnet if line.strip())
    file.truncate()

# %%
with open("willsmith.txt",'r+') as file:
    will = file.readlines()
    file.seek(0)
    file.writelines(line for line in will if line.strip())
    file.truncate()

# %%
def pickfrom(verses,no):
    #get a random no of lines from list of verses
    output="";
    lowerbound = len(verses)-no
    randomspot = randint(0,lowerbound)
    for i in range(0,no):
        output = output + verses[randomspot  + i] 
    return output

# %%
## Compose new Fresh Sonnets Output
output = ""
for i in range(1564): #year that shakespeare was born
    output= output+ pickfrom(will,3) 
    output= output + pickfrom(sonnet,2)

## Format into Sonnet Form octet then sextet
novel=""
count=0
octet=True 
chunked = output.split("\n")
for i in range(len(chunked)):
    count= count+1
    if count%8==0 and octet:
        chunked[i] = chunked[i]+'\n\n' 
        octet = not octet
        count=0
    elif count%6==0 and not octet:
        chunked[i] = chunked[i]+'\n\n' 
        octet = not octet
        count=0
print(chunked)

print(len(output.split())) #count those words!
# Out:
# ["No pager roll my hip as I'm rollin my whip", "Cause today I'm on the solo creep", 'Man, why you think I be workin so hard all week?', "And moan the expense of many a vanish'd sight:", 'Then can I grieve at grievances foregone,', "All of my people are lit so don't get in our way", "It's the kind of celebrity we need today", 'The force around me is strong, my light been burning long\n\n', 'In days long since, before these last so bad.', 'Thus is his cheek the map of days outworn,', '(Forever chasing forever)', 'I wanna stay, lets stay together', '(Lets stay together, forever, forever)', 'And this my hand, against my self uprear,\n\n', 'To guard the lawful reasons on thy part: ', 'Say yeah, yeah', "(I can't hear y'all)", 'Say yeah, yeah', 'And only herald to the gaudy spring,', 'Within thine own bud buriest thy content,', 'Just the two of us, you and I', 'Five years old, bringin comedy\n\n', 'Everytime I look at you I think man, a little me', 'So thou through windows of thine age shalt see,', 'Despite of wrinkles this thy golden time.', 'Come on, say what? Say what?', 'Yo Philly, come on, hey', 'Hey Tokyo, come on\n\n', 'But from thine eyes my knowledge I derive,', 'And constant stars in them I read such art', 'Look, just write your number right next to your name girl', "Ohh! I'm the party starter", 'You might have a good time but we party harder', 'She keeps thee to this purpose, that her skill', 'May time disgrace and wretched minutes kill.', 'Party in the city where the heat is on\n\n', 'Mmmts', 'Uhh (Doo-doo-doo-doo)', "Were't aught to me I bore the canopy,", 'With my extern the outward honouring,', 'Everyone, new millennium', "There's a party tonight\n\n", 'Everybody was drinking', 'That sin by him advantage should achieve,', 'And lace itself with his society? ', 'The Wild Wild West the Wild Wild..', "We're goin straight, to", 'The Wild Wild West', 'Upon thy part I can set down a story', "Of faults conceal'd, wherein I am attainted;\n\n", 'Better men better poet than me', 'Have tried to set verse to the love they knew', 'Dead to words judge what I do when I give you', "To linger out a purpos'd overthrow.", 'If thou wilt leave me, do not leave me last,', 'Now how we do it?\n\n', "(You know it's Big Willie style baby)", 'How we doing it?', 'At such who, not born fair, no beauty lack,', "Sland'ring creation with a false esteem:", "Now I ain't just messin wit'chu", "I got better things to do, I'm tryin' to help", 'I got a lesson for you, I know you do the best you could do', 'O! for my sake do you with Fortune chide,\n\n', 'The guilty goddess of my harmful deeds,', 'Just a lamp and a rub away from whatever you want', 'Habibi, lemme show you the dream (Habibi!)', "Just whisper if you don't wanna shout out what you need", 'Under the blow of thralled discontent,', "Whereto th' inviting time our fashion calls:\n\n", "And I just don't wanna stop", 'Never too much mever too much', 'Big Will', 'Lo, as a careful housewife runs to catch', "One of her feather'd creatures broke away,", 'Tell me if you want to rock just say (Ooo-oh!)', 'If you want to nod just say (Ooo-oh!)', 'Tell me if you want to rock just say (Ooo-oh!)\n\n', 'More flowers I noted, yet I none could see,', "But sweet, or colour it had stol'n from thee.", 'Somewhere to clear my mind (just cruisin)', "Just cruisin (I'm just cruisin)", "Where, baby, I don't care (just cruisin)", 'Being your slave what should I do but tend,\n\n', 'Upon the hours, and times of your desire?', "It's a shame to even have to discuss", "But it's no lip biting or pelvic thrusts, I mean", "You think that move'll put the sting on her?", "Whoe'er keeps me, let my heart be his guard;", 'Thou canst not then use rigour in my jail:', 'And flow to this fashion show', 'Pound for pound anywhere you go\n\n', "Yo, ain't no city in the world like this", 'And only herald to the gaudy spring,', 'Within thine own bud buriest thy content,', 'Came through the maze and the haze and played it', 'Perfect, dazed any pe ...
# 59704

# %%
#Print to text file
with open('freshsonnets.txt', 'w') as f:
    for line in chunked:
        f.write(line+'\n')

#Print to PDF
from fpdf import FPDF


class PDF(FPDF):
    def header(self):
        # Setting font: helvetica bold 15
        self.set_font("helvetica", "B", 15)
        # Calculating width of title and setting cursor position:
        width = self.get_string_width(self.title) + 6
        self.set_x((210 - width) / 2)
        # Setting colors for frame, background and text:
        self.set_draw_color(0, 80, 180)
        self.set_fill_color(200, 220, 255)
        self.set_text_color(220, 50, 50)
        # Setting thickness of the frame (1 mm)
        self.set_line_width(1)
        # Printing title:
        self.cell(width, 9, self.title, 1, 1, "C", True)
        # Performing a line break:
        self.ln(10)

    def footer(self):
        # Setting position at 1.5 cm from bottom:
        self.set_y(-15)
        # Setting font: helvetica italic 8
        self.set_font("helvetica", "I", 8)
        # Setting text color to gray:
        self.set_text_color(128)
        # Printing page number
        self.cell(0, 10, f"Page {self.page_no()}", 0, 0, "C")

    def chapter_title(self, label):
        # Setting font: helvetica 12
        self.set_font("helvetica", "", 12)
        # Setting background color
        self.set_fill_color(200, 220, 255)
        # Printing chapter name:
        self.cell(0, 6, f"{label}", 0, 1, "C", True)
        # Performing a line break:
        self.ln(4)

    def chapter_body(self, filepath):
        # Reading text file:
        with open(filepath, "rb") as fh:
            txt = fh.read().decode("latin-1")
        # Setting font: Times 12
        self.set_font("Times", size=12)
        # Printing justified text:
        self.multi_cell(0, 5, txt)
        # Performing a line break:
        self.ln()
        # Final mention in italics:
        self.set_font(style="I")
        self.cell(0, 5, "(--end--)")

    def print_chapter(self, title, filepath):
        self.add_page()
        self.chapter_title(title)
        self.chapter_body(filepath)


pdf = PDF()
pdf.set_title("Fresh Sonnets")
pdf.set_author("by anjchang for nanogenmo 2021")
pdf.print_chapter("Will Shakespeare Sonnets X Will Smith Rap | nanogenmo 2021 by anjchang", "freshsonnets.txt")
pdf.output("freshsonnets.pdf")
